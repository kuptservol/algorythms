# %%
from sklearn.linear_model import LinearRegression
import pandas as pd
import numpy as np

# %%
# !less train.tsv
# Out:
# 0.00508136      0.00273221      0.00397642      0.00453969      0.00473102      0.00506591      0.00255226      0.00355501      0.00367374      0.00408990      0.00515442      0.00248179      0.00410226      0.00005309      0.00230161      0.00144921      0.00330352      0.00315882      0.00178472      0.00331832      0.00004775      0.00051726      0.00057650      0.00378222      0.00270723      0.00344864      0.00212818      0.00480128      0.00303061      0.00239942      0.00012571      0.00179984      0.00390663      0.00028705      0.00238495      0.00322811      0.00434202      0.00354462      0.00019367      0.00417424      0.00343726      0.00195331      0.00192165      0.00472256      0.00343341      0.00509159      0.00479431      0.00456226      0.00522736      0.00121930      0.00134605      0.00165241      0.00238406      0.00379883      0.00144864      0.00313478      0.00187644      0.00432519      0.00180072      0.00128892      0.00248260      0.00135175      0.0043
# ...

# %%
train_rows = pd.read_csv('train.tsv', sep="\t", header=None)

# %%
train_rows.head(10)
# Out:
#             0             1             2         3             4         5    \
# 0  5.081360e-03  2.732210e-03  3.976420e-03  0.004540  4.731020e-03  0.005066
# 1  4.174910e-03  7.084480e-03  2.123510e-03  0.000003  3.681860e-03  0.004573
# 2  1.175410e-03  1.298870e-03  2.000290e-03  0.004009  3.330520e-03  0.004482
# 3  5.845890e-03  5.368910e-03  6.507510e-03  0.006121  8.502420e-03  0.008948
# 4  5.600000e-07  3.700000e-07  6.200000e-07  0.000002  9.700000e-07  0.000002
# 5  1.151580e-03  2.195450e-03  7.243100e-04  0.003271  9.266400e-04  0.004766
# 6  4.278200e-04  2.480950e-03  8.949300e-04  0.000270  1.707210e-03  0.000218
# 7  2.668000e-04  9.062700e-04  4.824000e-05  0.000940  7.450800e-04  0.000936
# 8  7.345100e-04  2.978660e-03  3.588700e-04  0.010333  5.323430e-03  0.010810
# 9  1.272728e-02  8.943260e-03  1.055854e-02  0.012072  3.793970e-03  0.001226
#
#         6         7         8             9      ...          91   \
# ...

# %%
X = train_rows.iloc[:, 0:100].values
y = train_rows.iloc[:, 100].values

# %%
y[0]
# Out:
# 0.28486006

# %%
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
coef = model.coef_

# %%
test_rows_ = pd.read_csv('test.tsv', sep="\t", header=None)

# %%
test_rows_.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.001625  0.001477  0.002368  0.004169  0.002668  0.002014  0.001802
# 1  0.004432  0.003121  0.003630  0.003058  0.000837  0.001640  0.001846
# 2  0.005194  0.004270  0.002174  0.000443  0.005398  0.001527  0.000288
# 3  0.014504  0.017867  0.002476  0.004764  0.008116  0.016214  0.011130
# 4  0.000413  0.000121  0.000385  0.000338  0.000413  0.000190  0.000306
#
#          7         8         9     ...           90        91        92  \
# 0  0.001962  0.003036  0.004454    ...     0.001312  0.001178  0.003841
# 1  0.001204  0.004186  0.003113    ...     0.001787  0.001105  0.000442
# 2  0.004906  0.005213  0.005860    ...     0.005762  0.000901  0.004286
# 3  0.009624  0.011102  0.006736    ...     0.002136  0.014053  0.004479
# 4  0.000034  0.000008  0.000124    ...     0.000353  0.000333  0.000290
#
#          93        94        95        96        97        98        99
# ...

# %%
test_rows = test_rows.values
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-7717424692f6> in <module>()
# ----> 1 test_rows = test_rows.values
#
# AttributeError: 'numpy.ndarray' object has no attribute 'values'

# %%
test_rows.shape
# Out:
# (1000, 100)

# %%
coef.shape
# Out:
# (100,)

# %%
test_res = np.matmul(np.array(test_rows), np.array(coef))

# %%
test_res.shape
# Out:
# (1000,)

# %%
test_res
# Out:
# array([0.25822782, 0.24118709, 0.29665102, 0.95457741, 0.02334326,
#        0.36751454, 0.19707804, 0.77752913, 0.90686134, 0.88359344,
#        0.05308194, 0.9794771 , 0.9556584 , 0.19200866, 0.55479525,
#        0.91739903, 0.32006895, 0.88116225, 0.90938282, 0.66715939,
#        0.29230975, 0.1894403 , 0.05936055, 0.83756917, 0.00705595,
#        0.64750468, 0.51855683, 0.02772997, 0.79370339, 0.93098786,
#        0.73718601, 0.42713718, 0.75573011, 0.17523983, 0.5954301 ,
#        0.23293957, 0.14870587, 0.23601125, 0.62775053, 0.03232687,
#        0.38919323, 0.47757061, 0.81279451, 0.58803419, 0.46969869,
#        0.99210591, 0.18528047, 0.57142602, 0.96803368, 0.20562342,
#        0.36481873, 0.18083921, 0.99709891, 0.69368137, 0.71839136,
#        0.47077571, 0.77205416, 0.42473482, 0.70205747, 0.85289158,
#        0.14177051, 0.84029226, 0.92966331, 0.5872018 , 0.85674237,
#        0.28510851, 0.88856574, 0.2781505 , 0.31797955, 0.05942245,
# ...

# %%
np.savetxt('answer.tsv', test_res, fmt='%.8f')
